# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
sns.set(style="white", context="talk")

# %%
imdb = pd.read_csv("imdb_1000.csv", sep=",")

# %%
imdb.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
imdb.shape                                     
#check the number of rows and columns - 979 rows, 6 columns
# Out:
# (979, 6)

# %%
imdb.duration.mean()                         
#calculate the average movie duration = 121. How to round?
# Out:
# 120.97957099080695

# %%
imdb.sort_values('duration').head() 
#sort the DataFrame by duration to find the shortest and longest movies: Freaks
# Out:
#      star_rating                        title content_rating    genre  \
# 389          8.0                       Freaks        UNRATED    Drama
# 338          8.0          Battleship Potemkin        UNRATED  History
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED    Crime
# 293          8.1                    Duck Soup         PASSED   Comedy
# 88           8.4                      The Kid      NOT RATED   Comedy
#
#      duration                                        actors_list
# 389        64  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...

# %%
imdb.sort_values('duration').tail() 
#sort the DataFrame by duration to find the shortest and longest movies: The Ten Commandments
# Out:
#      star_rating                              title content_rating      genre  \
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
#      duration                                        actors_list
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
imdb.describe() 
#trying to see if I can pull the min and max movies in one line.
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
imdb.duration.plot(kind="hist",bins=10)
#create a histogram of duration

# %%
imdb[["duration"]].plot(kind="box")
#use a box plot to display that same data

# %%
sns.boxplot(imdb[["duration"]])

# %%
sns.boxplot(x="genre",y="duration",data=imdb)
sns.stripplot(x="genre",y="duration",data=imdb,jitter=True)

# %%
#count how many movies have each of the content ratings
#use a visualization to display that same data, including a title and x and y labels
#convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP
#convert the following content ratings to "NC-17": X, TV-MA
#count the number of missing values in each column
#if there are missing values: examine them, then fill them in with "reasonable" values
#calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours
#use a visualization to detect whether there is a relationship between duration and star rating
#calculate the average duration for each genre

# %%
#count how many movies have each of the content ratings
imdb.star_rating.value_counts()
# Out:
# 7.6    124
# 7.8    116
# 7.7    113
# 7.5    108
# 8.1    103
# 8.0     97
# 7.9     75
# 8.2     51
# 7.4     49
# 8.3     43
# 8.4     37
# 8.5     23
# 8.6     15
# 8.7     10
# 8.9      6
# 8.8      5
# 9.2      1
# 9.3      1
# 9.1      1
# 9.0      1
# Name: star_rating, dtype: int64

# %%
#use a visualization to display that same data, including a title and x and y labels
imdb.hist(column='star_rating')
plt.ylabel("Number of movies")
plt.xlabel("Rating")
plt.title("Number of movies by star rating")
